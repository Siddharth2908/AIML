# %%
import pandas as pandas

# %%
import numpy as numpy

# %%
2+3
# Out:
# 5

# %%
pwd
# Out:
# 'C:\\Users\\1509456\\AIML\\Residency 3'

# %%
import os

# %%
os.chdir('C:\Siddhartha\Personal Documents\BOK\AIML')

# %%
Data = pandas.read_csv('parkinsons_data.csv')

# %%
Data.head(20)
# Out:
#               name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0   phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1   phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2   phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3   phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4   phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5   phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6   phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7   phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8   phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9   phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10  phon_R01_S02_5       88.333       112.240        84.072         0.00505
# ...

# %%
Data.shape
# Out:
# (195, 24)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
# name                195 non-null object
# MDVP:Fo(Hz)         195 non-null float64
# MDVP:Fhi(Hz)        195 non-null float64
# MDVP:Flo(Hz)        195 non-null float64
# MDVP:Jitter(%)      195 non-null float64
# MDVP:Jitter(Abs)    195 non-null float64
# MDVP:RAP            195 non-null float64
# MDVP:PPQ            195 non-null float64
# Jitter:DDP          195 non-null float64
# MDVP:Shimmer        195 non-null float64
# MDVP:Shimmer(dB)    195 non-null float64
# Shimmer:APQ3        195 non-null float64
# Shimmer:APQ5        195 non-null float64
# MDVP:APQ            195 non-null float64
# Shimmer:DDA         195 non-null float64
# NHR                 195 non-null float64
# HNR                 195 non-null float64
# status              195 non-null int64
# RPDE                195 non-null float64
# DFA                 195 non-null float64
# ...

# %%
Data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
Data[['MDVP:Fo(Hz)','MDVP:Fhi(Hz)']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 2 columns):
# MDVP:Fo(Hz)     195 non-null float64
# MDVP:Fhi(Hz)    195 non-null float64
# dtypes: float64(2)
# memory usage: 3.1 KB

# %%
Data[['MDVP:Fo(Hz)','MDVP:Fhi(Hz)']].describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)
# count   195.000000    195.000000
# mean    154.228641    197.104918
# std      41.390065     91.491548
# min      88.333000    102.145000
# 25%     117.572000    134.862500
# 50%     148.790000    175.829000
# 75%     182.769000    224.205500
# max     260.105000    592.030000

# %%
Data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer    ...     \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374    ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134    ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233    ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492    ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
Data.loc[1:3]
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer    ...     \
# 1           0.00008   0.00465   0.00696     0.01394       0.06134    ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233    ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
#
#     spread2        D2       PPE
# 1  0.335590  2.486855  0.368674
# ...

# %%
Data.iloc[0:2,1:3]
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)
# 0      119.992       157.302
# 1      122.400       148.650

# %%
Data.drop('MDVP:Fo(Hz)',axis=1)
# Out:
#                name  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1       157.302        74.997         0.00784
# 1    phon_R01_S01_2       148.650       113.819         0.00968
# 2    phon_R01_S01_3       131.111       111.555         0.01050
# 3    phon_R01_S01_4       137.871       111.366         0.00997
# 4    phon_R01_S01_5       141.781       110.655         0.01284
# 5    phon_R01_S01_6       131.162       113.787         0.00968
# 6    phon_R01_S02_1       137.244       114.820         0.00333
# 7    phon_R01_S02_2       113.840       104.315         0.00290
# 8    phon_R01_S02_3       132.068        91.754         0.00551
# 9    phon_R01_S02_4       120.103        91.226         0.00532
# 10   phon_R01_S02_5       112.240        84.072         0.00505
# 11   phon_R01_S02_6       115.871        86.292         0.00540
# 12   phon_R01_S04_1       159.866       131.276         0.00293
# 13   phon_R01_S04_2       179.139        76.556         0.00390
# ...

# %%
Data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer    ...     \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374    ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134    ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233    ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492    ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
Data.drop(0)
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5    phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6    phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7    phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8    phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9    phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10   phon_R01_S02_5       88.333       112.240        84.072         0.00505
# 11   phon_R01_S02_6       91.904       115.871        86.292         0.00540
# ...

# %%
Data.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
Data[Data['MDVP:Fo(Hz)']>100]
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5    phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6    phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7    phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 12   phon_R01_S04_1      136.926       159.866       131.276         0.00293
# 13   phon_R01_S04_2      139.173       179.139        76.556         0.00390
# 14   phon_R01_S04_3      152.845       163.305        75.836         0.00294
# ...

# %%
c = Data.groupby('MDVP:Fo(Hz)')

# %%
c
# Out:
#                        name  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)
# 88.333       phon_R01_S02_5       112.240        84.072         0.00505
# 91.904       phon_R01_S02_6       115.871        86.292         0.00540
# 95.056       phon_R01_S02_4       120.103        91.226         0.00532
# 95.385       phon_R01_S20_1       102.145        90.264         0.00608
# 95.605       phon_R01_S20_4       107.715        87.549         0.00702
# 95.730       phon_R01_S02_3       132.068        91.754         0.00551
# 96.106       phon_R01_S20_3       108.664        84.510         0.00694
# 98.804       phon_R01_S20_6       102.305        87.804         0.00432
# 100.770      phon_R01_S20_2       115.697        85.545         0.01038
# 100.960      phon_R01_S20_5       110.019        95.628         0.00606
# 102.273      phon_R01_S39_6       142.830        85.902         0.00907
# 104.400      phon_R01_S06_2       206.002        77.968         0.00633
# ...

# %%
Data.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       195.0  154.228641  41.390065   88.333000  117.572000
# MDVP:Fhi(Hz)      195.0  197.104918  91.491548  102.145000  134.862500
# MDVP:Flo(Hz)      195.0  116.324631  43.521413   65.476000   84.291000
# MDVP:Jitter(%)    195.0    0.006220   0.004848    0.001680    0.003460
# MDVP:Jitter(Abs)  195.0    0.000044   0.000035    0.000007    0.000020
# MDVP:RAP          195.0    0.003306   0.002968    0.000680    0.001660
# MDVP:PPQ          195.0    0.003446   0.002759    0.000920    0.001860
# Jitter:DDP        195.0    0.009920   0.008903    0.002040    0.004985
# MDVP:Shimmer      195.0    0.029709   0.018857    0.009540    0.016505
# MDVP:Shimmer(dB)  195.0    0.282251   0.194877    0.085000    0.148500
# Shimmer:APQ3      195.0    0.015664   0.010153    0.004550    0.008245
# Shimmer:APQ5      195.0    0.017878   0.012024    0.005700    0.009580
# ...

# %%
Data.kurtosis()
# Out:
# MDVP:Fo(Hz)         -0.627898
# MDVP:Fhi(Hz)         7.627241
# MDVP:Flo(Hz)         0.654615
# MDVP:Jitter(%)      12.030939
# MDVP:Jitter(Abs)    10.869043
# MDVP:RAP            14.213798
# MDVP:PPQ            11.963922
# Jitter:DDP          14.224762
# MDVP:Shimmer         3.238308
# MDVP:Shimmer(dB)     5.128193
# Shimmer:APQ3         2.720152
# Shimmer:APQ5         3.874210
# MDVP:APQ            11.163288
# Shimmer:DDA          2.720661
# NHR                 21.994974
# HNR                  0.616036
# status              -0.595518
# RPDE                -0.921781
# DFA                 -0.686152
# spread1             -0.050199
# spread2             -0.083023
# D2                   0.220334
# PPE                  0.528335
# dtype: float64

# %%
Data.skew()
# Out:
# MDVP:Fo(Hz)         0.591737
# MDVP:Fhi(Hz)        2.542146
# MDVP:Flo(Hz)        1.217350
# MDVP:Jitter(%)      3.084946
# MDVP:Jitter(Abs)    2.649071
# MDVP:RAP            3.360708
# MDVP:PPQ            3.073892
# Jitter:DDP          3.362058
# MDVP:Shimmer        1.666480
# MDVP:Shimmer(dB)    1.999389
# Shimmer:APQ3        1.580576
# Shimmer:APQ5        1.798697
# MDVP:APQ            2.618047
# Shimmer:DDA         1.580618
# NHR                 4.220709
# HNR                -0.514317
# status             -1.187727
# RPDE               -0.143402
# DFA                -0.033214
# spread1             0.432139
# spread2             0.144430
# D2                  0.430384
# PPE                 0.797491
# dtype: float64
